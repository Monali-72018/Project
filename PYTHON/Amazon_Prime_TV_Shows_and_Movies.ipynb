# %% [markdown]
# # **Project Name** - Amazon Prime TV Shows and Movies (Exploratory Data Analysis)
# bold textProject Type - EDA
# Contribution - Individual
# Name - Monali Lad

# %% [markdown]
# # **Project Summary**
#
# In the era of digital entertainment, streaming platforms such as Amazon Prime Video have become dominant players, offering audiences across the globe a wide variety of movies, TV shows, and original productions. With the massive growth in streaming content, understanding the trends, preferences, and underlying patterns in such a vast library of titles is both fascinating and valuable. This project focuses on conducting an in-depth Exploratory Data Analysis (EDA) of Amazon Prime content using two key datasets: one containing detailed title information (titles.csv) and another capturing cast and crew details (credits.csv). Together, these datasets provide a comprehensive view of what Amazon Prime offers, how content has evolved over the years, and what factors might influence ratings and popularity.
#
# The project begins by examining content distribution, analyzing the balance between movies and TV shows, release trends across years, and the average duration of films and series. This helps us understand how Amazon Prime has positioned its content portfolio and whether there has been a shift in production strategies over time. For instance, by studying year-wise release patterns, we can identify growth phases and explore how streaming platforms have adapted to global demand, particularly during significant events like the COVID-19 pandemic.
#
# A key focus of the analysis is on genres, as they form the backbone of audience preferences. By identifying the most common genres, their frequency, and their performance in terms of IMDb and TMDB ratings, we can highlight which types of content resonate most with viewers. Tracking genre popularity across decades also reveals how audience tastes have evolved. For example, genres like drama and comedy have historically dominated, while genres such as documentary and thriller have gained traction in recent years. This provides valuable insights into content creation trends and how Amazon Prime caters to diverse audience needs.
#
# Another crucial dimension explored is ratings and popularity. IMDb scores, votes, and TMDB ratings are used to measure quality and audience engagement. By analyzing the distribution of ratings, the correlation between IMDb and TMDB scores, and the relationship between votes and popularity, we gain a better understanding of what drives viewer satisfaction and recognition. Highlighting the highest-rated and most-voted content gives an indication of timeless classics as well as current audience favorites.
#
# The project also delves into age certifications, shedding light on how Amazon Prime addresses audience segments based on maturity ratings. By examining the distribution of content across certifications such as G, PG, PG-13, and R, we can determine whether the platform is more family-oriented or targeted towards mature audiences. Furthermore, comparing ratings across certifications provides insights into whether content targeted towards certain age groups tends to perform better critically.
#
# From a global perspective, country-wise analysis helps uncover the geographical diversity of Amazon Prime’s library. By identifying leading content-producing nations, analyzing US vs. non-US contributions, and comparing average ratings by country, we gain insights into international representation. A visual representation through a world map further strengthens this global outlook.
#
# The inclusion of the credits.csv dataset allows for cast and crew analysis, which provides a human-centric dimension to the study. Identifying the most frequent actors, directors, and writers highlights the creative contributors behind the platform’s success. Furthermore, evaluating their contribution in terms of frequency and average ratings adds depth to understanding how much influence star power and creative direction have on audience reception.
#
# Finally, the project investigates time-based trends and engagement metrics such as IMDb votes and TMDB popularity. By looking at decade-wise content growth, runtime patterns, and the evolution of genres, we trace the historical journey of entertainment on Amazon Prime. Engagement metrics further reveal the gap between critical acclaim and audience attention, helping us understand the interplay between quality and popularity.
#
# In summary, this project provides a holistic view of Amazon Prime’s content strategy and audience reception through comprehensive exploratory data analysis. By combining statistical KPIs with visual storytelling, we uncover patterns that not only describe the present landscape of Amazon Prime’s library but also point towards emerging trends in the global streaming industry. The insights from this study can be leveraged by content creators, streaming platforms, and even audiences to understand what makes content engaging, successful, and impactful in today’s digital entertainment era.

# %% [markdown]
# ![primevideo-seo-logo.png](data:image/png;base64,...)

# %% [markdown]
# GitHub Link
#
# [GitHUb Link](https://github.com/Monali-72018/Monali-Topscode)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# With the rapid expansion of streaming platforms like Amazon Prime Video, understanding the vast library of content has become a challenge. The platform hosts thousands of movies and shows across different genres, countries, and age groups, making it essential to analyze patterns that drive popularity and audience engagement. However, the data is scattered across multiple attributes such as ratings, runtime, cast, and genres, which makes it difficult to identify clear insights. This project aims to perform exploratory data analysis to uncover meaningful trends, evaluate content distribution, and highlight factors that contribute to the success and global reach of Amazon Prime’s content.

# %% [markdown]
# # **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze Amazon Prime’s content library to uncover insights that can support data-driven decision-making for content strategy. By examining trends in genres, ratings, release years, popularity, and cast/crew contributions, the goal is to identify what resonates most with audiences. This analysis will help in understanding viewer preferences, optimizing content acquisition or production, and enhancing customer satisfaction. Ultimately, the insights aim to support Amazon Prime in strengthening its competitive edge in the global streaming market.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# # ***1. Know Your Data***

# %% [markdown]
# **Import Libraries**

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset Loading

# %%
# Load Dataset
title_df = pd.read_csv('/content/titles.csv')

# %%
credit_df = pd.read_csv('/content/credits.csv')

# %% [markdown]
# # Dataset First View

# %%
# Dataset First Look
title_df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# 0  ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1  ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 2                        ['romance', 'war', 'drama']               ['US']
# 3                     ['comedy', 'drama', 'romance']               ['US']
# 4                   ['thriller', 'drama', 'romance']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0     26.0  tt0850645         8.6      1092.0           15.424         7.6
# 1      NaN  tt0017925         8.2     89766.0            8.647         8.0
# 2      NaN  tt0036868         8.1     63026.0            8.435         7.8
# 3      NaN  tt0032599         7.8     57835.0           11.270         7.4
# 4      NaN  tt0042593         7.9     30924.0            8.273         7.6

# %%
credit_df.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# # Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
title_df.shape
# Out:
# (9871, 15)

# %%
credit_df.shape
# Out:
# (124235, 5)

# %% [markdown]
# # Dataset Information

# %%
# Dataset Information
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# # Duplicate Values

# %%
#  Dataset Duplicate Value Count
title_df.duplicated().sum()
# Out:
# np.int64(3)

# %%
credit_df.duplicated().sum()
# Out:
# np.int64(56)

# %% [markdown]
# # Missing Values/Null Values

# %%
# Missing Values/Null Values Count
title_df.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Visualizing the missing values
credit_df.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %% [markdown]
# # What did you know about your dataset?

# %% [markdown]
# After getting the first view and some basic investigation I have found that there are 9871 rows & 15 columns in title_df dataframe and 124235 rows & 5 columns in the credit_df dataframe. We also found for duplicated values and found 3 duplicate values in title_df dataframe & 56 duplictate values in credit_df dataframe. We also found for null values and found these number of null values respectively. description-119, age_certification-6487, seasons-8514, imdb_id-667, imdb_score-1021, imdb_votes-1031, tmdb_popularity-547, tmdb_score-2082, character-16287.

# %% [markdown]
# # ***2. Understanding Your Variables***

# %%
# Dataset columns
title_df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
credit_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
title_df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# max        1437.906000    10.000000

# %%
credit_df.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# # Variables Description

# %% [markdown]
# The project uses two datasets — titles.csv and credits.csv — containing detailed information about Amazon Prime content. The titles dataset includes variables such as title, type (Movie/Show), release_year, runtime, genres, age_certification, production_countries, imdb_score, and tmdb_popularity, which describe each piece of content’s characteristics and performance. The credits dataset provides information on the people involved in the content, including name, character, and role (Actor, Director, or Writer). Together, these variables allow for a comprehensive analysis of content distribution, quality, audience ratings, and the creative contributors behind Amazon Prime’s library.

# %% [markdown]
# # Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
title_df.nunique()
# Out:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %%
credit_df.nunique()
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# # **3. Data Wrangling**

# %% [markdown]
# # Data Wrangling Code

# %%
#Replacing NaN values with 'Not Rated' in the age_certification column
title_df['age_certification'].fillna('Not Rated', inplace=True)

#Filling null values with mean values in imdb score column
title_df['imdb_score'].fillna(title_df['imdb_score'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_3119/1482721835.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   title_df['age_certification'].fillna('Not Rated', inplace=True)
# /tmp/ipykernel_3119/1482721835.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   title_df['imdb_score'].fillna(title_df['imdb_score'].mean(), inplace=True)

# %%
title_df.head(5)
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1         Not Rated       78
# 2         Not Rated      171
# 3         Not Rated       92
# 4         Not Rated       94
#
#                                               genres production_countries  \
# 0  ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1  ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 2                        ['romance', 'war', 'drama']               ['US']
# 3                     ['comedy', 'drama', 'romance']               ['US']
# 4                   ['thriller', 'drama', 'romance']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0     26.0  tt0850645         8.6      1092.0           15.424         7.6
# 1      NaN  tt0017925         8.2     89766.0            8.647         8.0
# 2      NaN  tt0036868         8.1     63026.0            8.435         7.8
# 3      NaN  tt0032599         7.8     57835.0           11.270         7.4
# 4      NaN  tt0042593         7.9     30924.0            8.273         7.6

# %%
#Dropping duplicate values from both title_df and credit_df
title_df.drop_duplicates(inplace=True)
credit_df.drop_duplicates(inplace=True)

# %%
#Merging title_df dataset and credit_df dataset using 'id' as primary key
merged_df = title_df.merge(credit_df, on='id', how='left')

# %%
merged_df
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 125349  tm1054116           Baikunth  MOVIE
# 125350  tm1054116           Baikunth  MOVIE
# 125351  tm1054116           Baikunth  MOVIE
# 125352  tm1054116           Baikunth  MOVIE
# 125353   ts275838   Waking Up Eighty   SHOW
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# 4       During America’s Civil War, Union spies steal ...          1926
# ...                                                   ...           ...
# 125349  This story is about prevalent caste problem, e...          2021
# 125350  This story is about prevalent caste problem, e...          2021
# 125351  This story is about prevalent caste problem, e...          2021
# 125352  This story is about prevalent caste problem, e...          2021
# 125353  Kara Stewart, 16, is fed up with just about ev...          2021
#
#        age_certification  runtime  \
# 0                  TV-PG       19
# 1                  TV-PG       19
# 2                  TV-PG       19
# 3                    NaN       78
# 4                    NaN       78
# ...                  ...      ...
# 125349               NaN       72
# 125350               NaN       72
# 125351               NaN       72
# 125352               NaN       72
# 125353               NaN       10
#
#                                                    genres  \
# 0       ['comedy', 'family', 'animation', 'action', 'f...
# 1       ['comedy', 'family', 'animation', 'action', 'f...
# 2       ['comedy', 'family', 'animation', 'action', 'f...
# 3       ['action', 'drama', 'war', 'western', 'comedy'...
# 4       ['action', 'drama', 'war', 'western', 'comedy'...
# ...                                                   ...
# 125349                                ['family', 'drama']
# 125350                                ['family', 'drama']
# 125351                                ['family', 'drama']
# 125352                                ['family', 'drama']
# 125353                                          ['drama']
#
#        production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                    ['US']     26.0   tt0850645         8.6      1092.0
# 1                    ['US']     26.0   tt0850645         8.6      1092.0
# 2                    ['US']     26.0   tt0850645         8.6      1092.0
# 3                    ['US']      NaN   tt0017925         8.2     89766.0
# 4                    ['US']      NaN   tt0017925         8.2     89766.0
# ...                     ...      ...         ...         ...         ...
# 125349                   []      NaN  tt14331982         8.4        49.0
# 125350                   []      NaN  tt14331982         8.4        49.0
# 125351                   []      NaN  tt14331982         8.4        49.0
# 125352                   []      NaN  tt14331982         8.4        49.0
# 125353                   []      1.0  tt13542552         NaN         NaN
#
#         tmdb_popularity  tmdb_score  person_id           name      character  \
# 0                15.424         7.6    59401.0     Joe Besser            Joe
# 1                15.424         7.6    31460.0     Moe Howard            Moe
# 2                15.424         7.6    31461.0     Larry Fine          Larry
# 3                 8.647         8.0    21174.0  Buster Keaton    Johnny Gray
# 4                 8.647         8.0    28713.0    Marion Mack  Annabelle Lee
# ...                 ...         ...        ...            ...            ...
# 125349            0.645         NaN  1938565.0   Vijay Thakur  Sanjay Thakur
# 125350            0.645         NaN   728899.0  Vanya Wellens        Budhiya
# 125351            0.645         NaN  1938620.0   Vishwa Bhanu          Gissu
# 125352            0.645         NaN  1938620.0   Vishwa Bhanu            NaN
# 125353              NaN         NaN        NaN            NaN            NaN
#
#             role
# 0          ACTOR
# 1          ACTOR
# 2          ACTOR
# 3          ACTOR
# 4          ACTOR
# ...          ...
# 125349     ACTOR
# 125350     ACTOR
# 125351     ACTOR
# 125352  DIRECTOR
# 125353       NaN
#
# [125354 rows x 19 columns]

# %%
#Creating a column for decade
title_df['decade'] = (title_df['release_year'] // 10) * 10

# %%
title_df['decade']
# Out:
# 0       1930
# 1       1920
# 2       1940
# 3       1940
# 4       1950
#         ...
# 9866    2020
# 9867    2020
# 9868    2020
# 9869    2020
# 9870    2020
# Name: decade, Length: 9871, dtype: int64

# %%
#Add new Column runtime_category for Categorize runtime into Short, Medium, or Long
merged_df['runtime_category'] = ''
for i in range(len(merged_df)):
    if merged_df.loc[i, 'runtime'] < 30:
        merged_df.loc[i, 'runtime_category'] = 'Short'
    elif merged_df.loc[i, 'runtime'] <= 90:
        merged_df.loc[i, 'runtime_category'] = 'Medium'
    else:
        merged_df.loc[i, 'runtime_category'] = 'Long'

# %%
merged_df
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 125349  tm1054116           Baikunth  MOVIE
# 125350  tm1054116           Baikunth  MOVIE
# 125351  tm1054116           Baikunth  MOVIE
# 125352  tm1054116           Baikunth  MOVIE
# 125353   ts275838   Waking Up Eighty   SHOW
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# 4       During America’s Civil War, Union spies steal ...          1926
# ...                                                   ...           ...
# 125349  This story is about prevalent caste problem, e...          2021
# 125350  This story is about prevalent caste problem, e...          2021
# 125351  This story is about prevalent caste problem, e...          2021
# 125352  This story is about prevalent caste problem, e...          2021
# 125353  Kara Stewart, 16, is fed up with just about ev...          2021
#
#        age_certification  runtime  \
# 0                  TV-PG       19
# 1                  TV-PG       19
# 2                  TV-PG       19
# 3                    NaN       78
# 4                    NaN       78
# ...                  ...      ...
# 125349               NaN       72
# 125350               NaN       72
# 125351               NaN       72
# 125352               NaN       72
# 125353               NaN       10
#
#                                                    genres  \
# 0       ['comedy', 'family', 'animation', 'action', 'f...
# 1       ['comedy', 'family', 'animation', 'action', 'f...
# 2       ['comedy', 'family', 'animation', 'action', 'f...
# 3       ['action', 'drama', 'war', 'western', 'comedy'...
# 4       ['action', 'drama', 'war', 'western', 'comedy'...
# ...                                                   ...
# 125349                                ['family', 'drama']
# 125350                                ['family', 'drama']
# 125351                                ['family', 'drama']
# 125352                                ['family', 'drama']
# 125353                                          ['drama']
#
#        production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                    ['US']     26.0   tt0850645         8.6      1092.0
# 1                    ['US']     26.0   tt0850645         8.6      1092.0
# 2                    ['US']     26.0   tt0850645         8.6      1092.0
# 3                    ['US']      NaN   tt0017925         8.2     89766.0
# 4                    ['US']      NaN   tt0017925         8.2     89766.0
# ...                     ...      ...         ...         ...         ...
# 125349                   []      NaN  tt14331982         8.4        49.0
# 125350                   []      NaN  tt14331982         8.4        49.0
# 125351                   []      NaN  tt14331982         8.4        49.0
# 125352                   []      NaN  tt14331982         8.4        49.0
# 125353                   []      1.0  tt13542552         NaN         NaN
#
#         tmdb_popularity  tmdb_score  person_id           name      character  \
# 0                15.424         7.6    59401.0     Joe Besser            Joe
# 1                15.424         7.6    31460.0     Moe Howard            Moe
# 2                15.424         7.6    31461.0     Larry Fine          Larry
# 3                 8.647         8.0    21174.0  Buster Keaton    Johnny Gray
# 4                 8.647         8.0    28713.0    Marion Mack  Annabelle Lee
# ...                 ...         ...        ...            ...            ...
# 125349            0.645         NaN  1938565.0   Vijay Thakur  Sanjay Thakur
# 125350            0.645         NaN   728899.0  Vanya Wellens        Budhiya
# 125351            0.645         NaN  1938620.0   Vishwa Bhanu          Gissu
# 125352            0.645         NaN  1938620.0   Vishwa Bhanu            NaN
# 125353              NaN         NaN        NaN            NaN            NaN
#
#             role runtime_category
# 0          ACTOR            Short
# 1          ACTOR            Short
# 2          ACTOR            Short
# 3          ACTOR           Medium
# 4          ACTOR           Medium
# ...          ...              ...
# 125349     ACTOR           Medium
# 125350     ACTOR           Medium
# 125351     ACTOR           Medium
# 125352  DIRECTOR           Medium
# 125353       NaN            Short
#
# [125354 rows x 20 columns]

# %%
#Add column is_movie (1 if movie, 0 if show)
merged_df['is_movie'] = 0
for i in range(len(merged_df)):
    if merged_df.loc[i, 'type'] == 'MOVIE':
        merged_df.loc[i, 'is_movie'] = 1
    else:
        merged_df.loc[i, 'is_movie'] = 0

# %%
merged_df
# Out:
#               id                            title   type  \
# 0        ts20945                The Three Stooges   SHOW
# 1        ts20945                The Three Stooges   SHOW
# 2        ts20945                The Three Stooges   SHOW
# 3        tm19248                      The General  MOVIE
# 4        tm19248                      The General  MOVIE
# ...          ...                              ...    ...
# 70536   tm510327                     Lily Is Here  MOVIE
# 70537  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 70538   tm847725                          Chasing  MOVIE
# 70539  tm1054116                         Baikunth  MOVIE
# 70540   ts275838                 Waking Up Eighty   SHOW
#
#                                              description  release_year  \
# 0      The Three Stooges were an American vaudeville ...          1934
# 1      The Three Stooges were an American vaudeville ...          1934
# 2      The Three Stooges were an American vaudeville ...          1934
# 3      During America’s Civil War, Union spies steal ...          1926
# 4      During America’s Civil War, Union spies steal ...          1926
# ...                                                  ...           ...
# 70536  Dallas and heroin have one thing in common: Du...          2021
# 70537  Something From Nothing takes you on a stand-up...          2021
# 70538  A cop from Chennai sets out to nab a dreaded d...          2021
# 70539  This story is about prevalent caste problem, e...          2021
# 70540  Kara Stewart, 16, is fed up with just about ev...          2021
#
#       age_certification  runtime  \
# 0                 TV-PG       19
# 1                 TV-PG       19
# 2                 TV-PG       19
# 3             Not Rated       78
# 4             Not Rated       78
# ...                 ...      ...
# 70536         Not Rated       93
# 70537         Not Rated       55
# 70538         Not Rated      116
# 70539         Not Rated       72
# 70540         Not Rated       10
#
#                                                   genres production_countries  \
# 0      ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1      ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 2      ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 3      ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 4      ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# ...                                                  ...                  ...
# 70536                                          ['drama']               ['US']
# 70537                                         ['comedy']               ['US']
# 70538                                          ['crime']               ['IN']
# 70539                                ['family', 'drama']                   []
# 70540                                          ['drama']                   []
#
#        seasons  ... imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0         26.0  ...   8.600000      1092.0           15.424         7.6
# 1         26.0  ...   8.600000      1092.0           15.424         7.6
# 2         26.0  ...   8.600000      1092.0           15.424         7.6
# 3          NaN  ...   8.200000     89766.0            8.647         8.0
# 4          NaN  ...   8.200000     89766.0            8.647         8.0
# ...        ...  ...        ...         ...              ...         ...
# 70536      NaN  ...   5.300000        20.0            1.406         NaN
# 70537      NaN  ...   5.976395         NaN            0.600         NaN
# 70538      NaN  ...   5.976395         NaN            1.960         NaN
# 70539      NaN  ...   8.400000        49.0            0.645         NaN
# 70540      1.0  ...   5.976395         NaN              NaN         NaN
#
#        person_id           name      character   role runtime_category  \
# 0        59401.0     Joe Besser            Joe  ACTOR            Short
# 1        31460.0     Moe Howard            Moe  ACTOR            Short
# 2        31461.0     Larry Fine          Larry  ACTOR            Short
# 3        21174.0  Buster Keaton    Johnny Gray  ACTOR           Medium
# 4        28713.0    Marion Mack  Annabelle Lee  ACTOR           Medium
# ...          ...            ...            ...    ...              ...
# 70536        NaN            NaN            NaN    NaN             Long
# 70537        NaN            NaN            NaN    NaN           Medium
# 70538        NaN            NaN            NaN    NaN             Long
# 70539        NaN            NaN            NaN    NaN           Medium
# 70540        NaN            NaN            NaN    NaN            Short
#
#       is_movie
# 0            0
# 1            0
# 2            0
# 3            1
# 4            1
# ...        ...
# 70536        1
# 70537        1
# 70538        1
# 70539        1
# 70540        0
#
# [70541 rows x 21 columns]

# %%
#Categorize IMDb ratings (Poor, Average, Good, Excellent)
merged_df['rating_category'] = ''
for i in range(len(merged_df)):
    score = merged_df.loc[i, 'imdb_score']
    if pd.isna(score):
        merged_df.loc[i, 'rating_category'] = 'Not Rated'
    elif score < 5:
        merged_df.loc[i, 'rating_category'] = 'Poor'
    elif score < 7:
        merged_df.loc[i, 'rating_category'] = 'Average'
    elif score < 8.5:
        merged_df.loc[i, 'rating_category'] = 'Good'
    else:
        merged_df.loc[i, 'rating_category'] = 'Excellent'

# %%
merged_df
# Out:
#               id                            title   type  \
# 0        ts20945                The Three Stooges   SHOW
# 1        ts20945                The Three Stooges   SHOW
# 2        ts20945                The Three Stooges   SHOW
# 3        tm19248                      The General  MOVIE
# 4        tm19248                      The General  MOVIE
# ...          ...                              ...    ...
# 70536   tm510327                     Lily Is Here  MOVIE
# 70537  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 70538   tm847725                          Chasing  MOVIE
# 70539  tm1054116                         Baikunth  MOVIE
# 70540   ts275838                 Waking Up Eighty   SHOW
#
#                                              description  release_year  \
# 0      The Three Stooges were an American vaudeville ...          1934
# 1      The Three Stooges were an American vaudeville ...          1934
# 2      The Three Stooges were an American vaudeville ...          1934
# 3      During America’s Civil War, Union spies steal ...          1926
# 4      During America’s Civil War, Union spies steal ...          1926
# ...                                                  ...           ...
# 70536  Dallas and heroin have one thing in common: Du...          2021
# 70537  Something From Nothing takes you on a stand-up...          2021
# 70538  A cop from Chennai sets out to nab a dreaded d...          2021
# 70539  This story is about prevalent caste problem, e...          2021
# 70540  Kara Stewart, 16, is fed up with just about ev...          2021
#
#       age_certification  runtime  \
# 0                 TV-PG       19
# 1                 TV-PG       19
# 2                 TV-PG       19
# 3             Not Rated       78
# 4             Not Rated       78
# ...                 ...      ...
# 70536         Not Rated       93
# 70537         Not Rated       55
# 70538         Not Rated      116
# 70539         Not Rated       72
# 70540         Not Rated       10
#
#                                                   genres production_countries  \
# 0      ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 1      ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 2      ['comedy', 'family', 'animation', 'action', 'f...               ['US']
# 3      ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# 4      ['action', 'drama', 'war', 'western', 'comedy'...               ['US']
# ...                                                  ...                  ...
# 70536                                          ['drama']               ['US']
# 70537                                         ['comedy']               ['US']
# 70538                                          ['crime']               ['IN']
# 70539                                ['family', 'drama']                   []
# 70540                                          ['drama']                   []
#
#        seasons  ... imdb_votes  tmdb_popularity  tmdb_score  person_id  \
# 0         26.0  ...     1092.0           15.424         7.6    59401.0
# 1         26.0  ...     1092.0           15.424         7.6    31460.0
# 2         26.0  ...     1092.0           15.424         7.6    31461.0
# 3          NaN  ...    89766.0            8.647         8.0    21174.0
# 4          NaN  ...    89766.0            8.647         8.0    28713.0
# ...        ...  ...        ...              ...         ...        ...
# 70536      NaN  ...       20.0            1.406         NaN        NaN
# 70537      NaN  ...        NaN            0.600         NaN        NaN
# 70538      NaN  ...        NaN            1.960         NaN        NaN
# 70539      NaN  ...       49.0            0.645         NaN        NaN
# 70540      1.0  ...        NaN              NaN         NaN        NaN
#
#                 name      character   role runtime_category is_movie  \
# 0         Joe Besser            Joe  ACTOR            Short        0
# 1         Moe Howard            Moe  ACTOR            Short        0
# 2         Larry Fine          Larry  ACTOR            Short        0
# 3      Buster Keaton    Johnny Gray  ACTOR           Medium        1
# 4        Marion Mack  Annabelle Lee  ACTOR           Medium        1
# ...              ...            ...    ...              ...      ...
# 70536            NaN            NaN    NaN             Long        1
# 70537            NaN            NaN    NaN           Medium        1
# 70538            NaN            NaN    NaN             Long        1
# 70539            NaN            NaN    NaN           Medium        1
# 70540            NaN            NaN    NaN            Short        0
#
#       rating_category
# 0           Excellent
# 1           Excellent
# 2           Excellent
# 3                Good
# 4                Good
# ...               ...
# 70536         Average
# 70537         Average
# 70538         Average
# 70539            Good
# 70540         Average
#
# [70541 rows x 22 columns]

# %% [markdown]
# # **4. KPIs ( Key Performance Indicators) Calculation**

# %%
#General Content Overview KPIs
total_titles = merged_df.shape[0]
total_movies = merged_df[merged_df['type'] == 'MOVIE'].shape[0]
total_shows = merged_df[merged_df['type'] == 'SHOW'].shape[0]
avg_runtime = merged_df['runtime'].mean()
avg_imdb = merged_df['imdb_score'].mean()
oldest_year = merged_df['release_year'].min()
newest_year = merged_df['release_year'].max()

print("Total Titles:", total_titles)
print("Movies:", total_movies)
print("Shows:", total_shows)
print("Average Runtime:", round(avg_runtime, 2))
print("Average IMDb Score:", round(avg_imdb, 2))
print("Release Years Range:", oldest_year, "-", newest_year)
# Out:
# Total Titles: 125354
# Movies: 116853
# Shows: 8501
# Average Runtime: 95.31
# Average IMDb Score: 5.97
# Release Years Range: 1912 - 2022

# %%
#Genre Based KPIs

# Split multiple genres into separate rows
genres_split = merged_df.dropna(subset=['genres']).copy()
genres_split['genres'] = genres_split['genres'].str.replace('[', '').str.replace(']', '').str.replace("'", "")
genres_split = genres_split.assign(genres=genres_split['genres'].str.split(','))
genres_split = genres_split.explode('genres')
genres_split['genres'] = genres_split['genres'].str.strip()

# %%
# Top 10 genres
top_genres = genres_split['genres'].value_counts().head(10)
print(top_genres)
# Out:
# genres
# drama       70102
# comedy      41493
# thriller    33079
# action      30400
# romance     28675
# crime       20672
# horror      14142
# european    12548
# scifi       11442
# fantasy      8935
# Name: count, dtype: int64

# %%
# Average IMDb by genre
avg_imdb_genre = genres_split.groupby('genres')['imdb_score'].mean().sort_values(ascending=False).head(10)
print(avg_imdb_genre)
# Out:
# genres
# documentation    6.971788
# history          6.693260
# reality          6.631620
# war              6.432608
# animation        6.395486
# european         6.338499
# sport            6.257388
# drama            6.235171
# romance          6.122010
# music            6.120097
# Name: imdb_score, dtype: float64

# %%
#Ratings & Quality KPIs

# Average IMDb and TMDB
avg_imdb = merged_df['imdb_score'].mean()
avg_tmdb = merged_df['tmdb_score'].mean()
print("Average IMDb:", round(avg_imdb,2), "Average TMDB:", round(avg_tmdb,2))

# Top 10 highest rated
top_rated = merged_df.sort_values('imdb_score', ascending=False).head(10)
print(top_rated[['title', 'imdb_score']])

# Correlation between IMDb and TMDB
correlation = merged_df['imdb_score'].corr(merged_df['tmdb_score'])
print("Correlation IMDb vs TMDB:", round(correlation,2))
# Out:
# Average IMDb: 5.97 Average TMDB: 5.99
#              title  imdb_score
# 119981  Pawankhind         9.9
# 119980  Pawankhind         9.9
# 119979  Pawankhind         9.9
# 119978  Pawankhind         9.9
# 119977  Pawankhind         9.9
# 119969  Pawankhind         9.9
# 119970  Pawankhind         9.9
# 119971  Pawankhind         9.9
# 119972  Pawankhind         9.9
# 119973  Pawankhind         9.9
# Correlation IMDb vs TMDB: 0.65

# %%
#Cast and Crew KPIs

# Top actors, directors, and writers
top_actors = merged_df[merged_df['role'] == 'ACTOR']['name'].value_counts().head(10)
top_directors = merged_df[merged_df['role'] == 'DIRECTOR']['name'].value_counts().head(10)
top_writers = merged_df[merged_df['role'] == 'WRITER']['name'].value_counts().head(10)

print("Top Actors:\n", top_actors)
print("Top Directors:\n", top_directors)
print("Top Writers:\n", top_writers)

# Role distribution
role_dist = merged_df['role'].value_counts()
print(role_dist)
# Out:
# Top Actors:
#  name
# George 'Gabby' Hayes    49
# Roy Rogers              45
# Bess Flowers            44
# Gene Autry              40
# Charles King            38
# Herman Hack             35
# Earl Dwire              34
# Forrest Taylor          34
# George Morrell          34
# Champion                32
# Name: count, dtype: int64
# Top Directors:
#  name
# Joseph Kane           41
# Sam Newfield          38
# Lesley Selander       22
# Harry L. Fraser       21
# John English          21
# William Nigh          20
# Robert N. Bradbury    17
# William Beaudine      16
# George Archainbaud    16
# Frank McDonald        14
# Name: count, dtype: int64
# Top Writers:
#  Series([], Name: count, dtype: int64)
# role
# ACTOR       60749
# DIRECTOR     3769
# DIRECTO         1
# Name: count, dtype: int64

# %%
#Country and Regional KPIs

# Split production countries
countries_split = merged_df.dropna(subset=['production_countries']).copy()
countries_split['production_countries'] = countries_split['production_countries'].str.replace('[', '').str.replace(']', '').str.replace("'", "")
countries_split = countries_split.assign(production_countries=countries_split['production_countries'].str.split(','))
countries_split = countries_split.explode('production_countries')
countries_split['production_countries'] = countries_split['production_countries'].str.strip()

# Top 10 countries
top_countries = countries_split['production_countries'].value_counts().head(10)
print(top_countries)
# Out:
# production_countries
# US    52240
# GB     6355
# IN     3432
# CA     3216
# FR     2514
# DE     2024
# IT     1922
# JP     1459
#         981
# ES      952
# Name: count, dtype: int64

# %%
#Age Certification KPIs

# Count of each certification
cert_count = merged_df['age_certification'].value_counts()
print(cert_count)
# Out:
# age_certification
# Not Rated    36324
# R            16114
# PG-13         7062
# PG            6339
# G             2756
# TV-14          537
# TV-MA          348
# TV-PG          293
# TV-Y7          290
# TV-Y           254
# TV-G           182
# NC-17           42
# Name: count, dtype: int64

# %%
# Average IMDb by certification
avg_imdb_cert = merged_df.groupby('age_certification')['imdb_score'].mean().sort_values(ascending=False)
print(avg_imdb_cert)
# Out:
# age_certification
# TV-MA        7.527179
# TV-PG        7.426299
# TV-14        7.190783
# TV-Y7        6.713468
# TV-G         6.522978
# TV-Y         6.253194
# PG           6.210400
# G            6.084884
# PG-13        6.033244
# Not Rated    6.001139
# R            5.966094
# NC-17        5.470867
# Name: imdb_score, dtype: float64

# %%
#Popularity and Engagement KPIs

# Top 10 popular titles
top_popular = merged_df.sort_values('tmdb_popularity', ascending=False).head(10)
print(top_popular[['title', 'tmdb_popularity']])

# Correlation between popularity & IMDb
popularity_corr = merged_df['tmdb_popularity'].corr(merged_df['imdb_score'])
print("Correlation between TMDB Popularity and IMDb Rating:", round(popularity_corr,2))
# Out:
#                                    title  tmdb_popularity
# 69604                 All the Old Knives         1437.906
# 69710                             Harina          951.863
# 69709                  The eighth clause          950.986
# 69634  Hotel Transylvania: Transformania          934.545
# 68091                 Sonic the Hedgehog          893.650
# 69618           Clifford the Big Red Dog          482.744
# 69762                    Queen of Spades          429.802
# 69681                            Meander          389.431
# 64769                              Suits          356.533
# 65957                   Better Call Saul          352.657
# Correlation between TMDB Popularity and IMDb Rating: 0.21

# %%
#Time and Trends KPIs

# Number of releases per year
release_trend = merged_df['release_year'].value_counts().sort_index()
print(release_trend)

# Average IMDb per year
avg_imdb_year = merged_df.groupby('release_year')['imdb_score'].mean()
print(avg_imdb_year)
# Out:
# release_year
# 1912     11
# 1914     33
# 1915     53
# 1916    126
# 1917      8
#        ...
# 2018    685
# 2019    807
# 2020    698
# 2021    856
# 2022     89
# Name: count, Length: 110, dtype: int64
# release_year
# 1912    5.800000
# 1914    5.521212
# 1915    6.088679
# 1916    7.483333
# 1917    6.300000
#           ...
# 2018    5.960972
# 2019    5.957422
# 2020    5.812042
# 2021    5.735394
# 2022    6.633756
# Name: imdb_score, Length: 110, dtype: float64

# %%
#Derived KPIs (from feature engineered columns)

# Average runtime by runtime category
avg_runtime_category = merged_df.groupby('runtime_category')['runtime'].mean()
print(avg_runtime_category)

# Average IMDb by rating category
avg_rating_category = merged_df.groupby('rating_category')['imdb_score'].mean()
print(avg_rating_category)
# Out:
# runtime_category
# Long      112.873695
# Medium     73.740978
# Short      21.335789
# Name: runtime, dtype: float64
# rating_category
# Average      6.010710
# Excellent    8.649469
# Good         7.458564
# Poor         4.160849
# Name: imdb_score, dtype: float64

# %% [markdown]
# # ***5. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# Chart - 1 Movies Vs TV Shows Count

# %%
# Movies VS Shows

merged_df['type'].value_counts().plot(kind='bar',color = ['teal','yellow'])
plt.title('Movies VS Shows On Amazon Prime')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Chart - 2 Release by Year

# %%
# Releases by Year

merged_df['release_year'].value_counts().sort_index().plot(kind='line',color='Purple')
plt.title('Content Released per Year')
plt.xlabel('Relese Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# # Chart - 3 Runtime Distribution

# %%
# Runtime Distribution

plt.hist(merged_df['runtime'].dropna(),bins=30,color='green',edgecolor='yellow')
plt.title('Distribution Of Movie Runtimes')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Chart - 4 Top 10 Genres by Count

# %%
# Top 10 Genres by Count

genres_split['genres'].value_counts().head(10).plot(kind='bar',color='cyan')
plt.title('Top 10 Genres by Count')
plt.xlabel('Genre')
plt.ylabel('Number Of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Chart - 5 Average IMDb by Genre (Top 10)

# %%
# Average IMDb by Genre (Top 10)

avg_imdb_genre.head(10).plot(kind='bar', color='coral')
plt.title('Top 10 Genres by Average IMDb Rating')
plt.xlabel('Genre')
plt.ylabel('Average IMDb')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Chart - 6 Genre Vs IMDb Heatmap

# %%
# Genre VS IMDb Heatmap

genre_pivot = genres_split.pivot_table(index='genres',values='imdb_score',aggfunc='mean').sort_values('imdb_score',ascending=False).head(15)
sns.heatmap(genre_pivot,annot=True,cmap='Blues')
plt.title('Average IMDb Rating by Genre')
plt.show()

# %% [markdown]
# # Chart - 7 IMDb Score Distribution

# %%
# IMDb Score Distribution

sns.histplot(merged_df['imdb_score'],bins=20,kde=True,color='blue')
plt.title('Distribution Of IMDb Scores')
plt.xlabel('IMDb Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Chart - 8 IMDb vs TMDB Correlation Scatterplot

# %%
# IMDb vs TMDB Correlation Scatterplot

sns.scatterplot(data=merged_df,x='imdb_score',y='tmdb_score',color='orange')
plt.title('IMDb vs TMDB Correlation')
plt.xlabel('IMDb Score')
plt.ylabel('TMDB Score')
plt.show()

# %% [markdown]
# # Chart - 9 Sort dataset by IMDb score (descending)

# %%
# Sort dataset by IMDb score (descending)
top_rated = merged_df.sort_values('imdb_score', ascending=False).head(10)

# Create barplot for Top 10 Highest Rated Titles
plt.figure(figsize=(10,6))
sns.barplot(data=top_rated, x='imdb_score', hue='title', palette='coolwarm')

# Chart labels and title
plt.title('Top 10 Highest Rated Titles on Amazon Prime', fontsize=14, weight='bold')
plt.xlabel('IMDb Score', fontsize=12)
plt.ylabel('Title', fontsize=12)

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# # Chart - 10 Top 10 Actors

# %%
# Top 10 Actors

top_actors.plot(kind='barh',color='Orange')
plt.title('Top 10 Most Frequent Actors')
plt.xlabel('Count')
plt.ylabel('Actor')
plt.show()

# %% [markdown]
# # Chart - 11 Top 10 Directors

# %%
# Top 10 Directors


top_directors.plot(kind='barh',color='plum')
plt.title('Top 10 Most Frequent Actors')
plt.xlabel('Count')
plt.ylabel('Actor')
plt.show()

# %% [markdown]
# # Chart - 12 Role Distribution

# %%
# Role Distribution

plt.figure(figsize=(8,8))
explode = (0.02, 0.12, 0.12)
role_dist.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'lightcoral', 'lightskyblue'], explode=explode,
pctdistance=0.75,labeldistance=1.1)
plt.title('Role Distribution (Actor, Director, Writer)')
plt.legend(
    labels=role_dist.index,
    title="Roles",
    loc="upper right"
)
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Chart - 13 Top 10 Production Countries

# %%
# Top 10 Production Countries

top_countries.plot(kind='bar', color='blue')
plt.title('Top 10 Production Countries')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Chart - 14 - Average IMDb by Country

# %%
# Average IMDb by Country

avg_imdb_country = countries_split.groupby('production_countries')['imdb_score'].mean().sort_values(ascending=False).head(10)
avg_imdb_country.plot(kind='bar', color='tomato')
plt.title('Top 10 Countries by Average IMDb Rating')
plt.xlabel('Country')
plt.ylabel('Average IMDb')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Chart - 15 - Certification Distribution

# %%
# Certification Distribution

merged_df['age_certification'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.legend(title='Age Certification', loc='best')
plt.title('Distribution by Age Certification')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Chart - 16 - Average IMDb by Certification

# %%
# Average IMDb by Certification

avg_imdb_cert.plot(kind='bar', color='orchid')
plt.title('Average IMDb Rating by Age Certification')
plt.xlabel('Certification')
plt.ylabel('Average IMDb')
plt.show()

# %% [markdown]
# # Chart - 17 - Top 10 Popular Titles

# %%
# Top 10 Popular Titles

sns.barplot(data=top_popular, x='tmdb_popularity', hue='title', palette='mako')
plt.title('Top 10 Most Popular Titles on Amazon Prime')
plt.xlabel('TMDB Popularity Score')
plt.ylabel('Title')
plt.show()

# %% [markdown]
# # Chart - 18 - Popularity vs IMDb Scatterplot

# %%
# Popularity vs IMDb Scatterplot

sns.scatterplot(data=merged_df, x='tmdb_popularity', y='imdb_score', color='darkgreen')
plt.title('Popularity vs IMDb Score')
plt.xlabel('TMDB Popularity')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# # Chart - 19 - IMDb Votes Trend (if available)

# %%
# IMDb Votes Trend (if available)

if 'imdb_votes' in merged_df.columns:
    merged_df.groupby('release_year')['imdb_votes'].mean().plot(kind='line', color='blue')
    plt.title('Average IMDb Votes per Year')
    plt.xlabel('Year')
    plt.ylabel('Average Votes')
    plt.show()

# %% [markdown]
# # Chart - 20 - Total Releases per Year

# %%
# Total Releases per Year

merged_df['release_year'].value_counts().sort_index().plot(kind='line', color='brown')
plt.title('Number of Releases Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# # Chart - 21 - Average IMDb per Year

# %%
# Average IMDb per Year

avg_imdb_year.plot(kind='line', color='navy')
plt.title('Average IMDb Rating Over the Years')
plt.xlabel('Year')
plt.ylabel('Average IMDb Score')
plt.show()

# %% [markdown]
# # Chart - 22-Runtime Trend Over Years

# %%
# Runtime Trend Over Years

sns.lineplot(data=merged_df, x='release_year', y='runtime', color='teal')
plt.title('Average Runtime Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Runtime (minutes)')
plt.show()

# %% [markdown]
# # Chart - 23 - Average IMDb by Rating Category

# %%
# Average IMDb by Rating Category

avg_rating_category.plot(kind='bar', color='salmon')
plt.title('Average IMDb by Rating Category')
plt.xlabel('Rating Category')
plt.ylabel('Average IMDb')
plt.show()

# %% [markdown]
# Chart - 24 - Average Runtime by Runtime Category

# %%
# Average Runtime by Runtime Category

avg_runtime_category.plot(kind='bar', color='lightblue')
plt.title('Average Runtime by Runtime Category')
plt.xlabel('Runtime Category')
plt.ylabel('Average Runtime (minutes)')
plt.show()

# %% [markdown]
# # Chart - 25 - Runtime vs IMDb Scatter

# %%
# Runtime vs IMDb Scatter

sns.scatterplot(data=merged_df, x='runtime', y='imdb_score', color='purple')
plt.title('Runtime vs IMDb Score')
plt.xlabel('Runtime')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# # **6. Solution to Business Objective**

# %% [markdown]
# # What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Amazon Prime should focus on expansion and promotion of content in the hottest genres and regions identified by data insights to meet its business objectives. Investing in well-performing categories including top genres and saying yes to working with high-engagement actors or directors can improve audience engagement. It should also study the interest of viewers in terms of IMDb and TMDB ratings to suggest content accordingly. Having a combination of newly released and classic titles will also help to capture different audiences. Using these insights, Amazon Prime primeining its contentsystemiteer and hold that point.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Amazon Prime Exploratory Data Analysis provided valuable insights into the platform’s content trends, audience preferences, and performance metrics. The study revealed that factors such as genre popularity, release year distribution, and IMDb/TMDB scores play a significant role in determining the success of shows and movies. By analyzing key patterns in ratings, content type, and regional contributions, the project highlights opportunities for Amazon Prime to enhance its content strategy and audience targeting. These findings can help the platform make informed decisions about future investments, improve viewer satisfaction, and maintain a competitive advantage in the rapidly evolving streaming industry. Overall, this data-driven approach demonstrates the power of analytics in shaping business success for entertainment platforms.
